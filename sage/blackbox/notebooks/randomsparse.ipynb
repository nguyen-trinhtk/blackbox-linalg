# %%
import sys
import os
modules_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'modules'))
if modules_path not in sys.path:
    sys.path.insert(0, modules_path)
from generators import *
from wiedemann import *
from random import random

# %%
def test_random_matrices(num_tests):
    i = 0
    failed = 0
    while i < num_tests:
        i += 1
        try:
            print('---')
            print(f'Case {i}...', end=' ')
            sparsity = 0.85 + (0.95 - 0.85) * random() # Random sparsity in [0.85, 0.95]
            A, b, dim, field = generate_linear_system(sparsity = sparsity)
            wiedemann_timed_test(A, b, dim, field)
        except Exception as e:
            print(f'Failed: {e}')
            failed += 1
    print('==="
    print(f'Failed {failed} cases')

# %%
test_random_matrices(30)
# Out:
# ---
# Case 1... Valid solution: attempt #1
# Finished Wiedemann in 0.338s (1 attempt)
# Solution verified against Sage built-in solver (0.005s)
# Wiedemann generated min poly is correct
# ---
# Case 2... Valid solution: attempt #1
# Finished Wiedemann in 2.056s (1 attempt)
# Solution verified against Sage built-in solver (0.024s)
# Wiedemann generated min poly is correct
# ---
# Case 3... Valid solution: attempt #1
# Finished Wiedemann in 4.631s (1 attempt)
# Solution verified against Sage built-in solver (0.040s)
# Wiedemann generated min poly is correct
# ---
# Case 4... Valid solution: attempt #1
# Finished Wiedemann in 1.461s (1 attempt)
# Solution verified against Sage built-in solver (0.014s)
# Wiedemann generated min poly is correct
# ---
# Case 5... Valid solution: attempt #1
# Finished Wiedemann in 0.965s (1 attempt)
# Solution verified against Sage built-in solver (0.010s)
# Wiedemann generated min poly is correct
# ---
# Case 6... Valid solution: attempt #1
# Finished Wiedemann in 1.428s (1 attempt)
# Solution verified against Sage built-in solver (0.016s)
# Wiedemann generated min poly is correct
# ---
# Case 7... Valid solution: attempt #1
# Finished Wiedemann in 4.186s (1 attempt)
# Solution verified against Sage built-in solver (0.037s)
# Wiedemann generated min poly is correct
# ---
# Case 8... Valid solution: attempt #1
# Finished Wiedemann in 1.813s (1 attempt)
# Solution verified against Sage built-in solver (0.020s)
# Wiedemann generated min poly is correct
# ---
# Case 9... Valid solution: attempt #1
# Finished Wiedemann in 3.000s (1 attempt)
# Solution verified against Sage built-in solver (0.028s)
# Wiedemann generated min poly is correct
# ---
# Case 10... Valid solution: attempt #1
# Finished Wiedemann in 2.896s (1 attempt)
# Solution verified against Sage built-in solver (0.031s)
# Wiedemann generated min poly is correct
# ---
# Case 11... Valid solution: attempt #1
# Finished Wiedemann in 3.209s (1 attempt)
# Solution verified against Sage built-in solver (0.031s)
# Wiedemann generated min poly is correct
# ---
# Case 12... Valid solution: attempt #1
# Finished Wiedemann in 1.654s (1 attempt)
# Solution verified against Sage built-in solver (0.020s)
# Wiedemann generated min poly is correct
# ---
# Case 13... Valid solution: attempt #1
# Finished Wiedemann in 2.275s (1 attempt)
# Solution verified against Sage built-in solver (0.021s)
# Wiedemann generated min poly is correct
# ---
# Case 14... Valid solution: attempt #1
# Finished Wiedemann in 1.077s (1 attempt)
# Solution verified against Sage built-in solver (0.068s)
# Wiedemann generated min poly is correct
# ---
# Case 15... Valid solution: attempt #1
# Finished Wiedemann in 0.506s (1 attempt)
# Solution verified against Sage built-in solver (0.008s)
# Wiedemann generated min poly is correct
# ---
# Case 16... Valid solution: attempt #1
# Finished Wiedemann in 4.405s (1 attempt)
# Solution verified against Sage built-in solver (0.037s)
# Wiedemann generated min poly is correct
# ---
# Case 17... Valid solution: attempt #1
# Finished Wiedemann in 0.454s (1 attempt)
# Solution verified against Sage built-in solver (0.006s)
# Wiedemann generated min poly is correct
# ---
# Case 18... Valid solution: attempt #1
# Finished Wiedemann in 2.428s (1 attempt)
# Solution verified against Sage built-in solver (0.022s)
# Wiedemann generated min poly is correct
# ---
# Case 19... Valid solution: attempt #1
# Finished Wiedemann in 0.845s (1 attempt)
# Solution verified against Sage built-in solver (0.009s)
# Wiedemann generated min poly is correct
# ---
# Case 20... Valid solution: attempt #1
# Finished Wiedemann in 2.070s (1 attempt)
# Solution verified against Sage built-in solver (0.026s)
# Wiedemann generated min poly is correct
# ---
# Case 21... Valid solution: attempt #1
# Finished Wiedemann in 0.238s (1 attempt)
# Solution verified against Sage built-in solver (0.004s)
# Wiedemann generated min poly is correct
# ---
# Case 22... Valid solution: attempt #1
# Finished Wiedemann in 1.539s (1 attempt)
# Solution verified against Sage built-in solver (0.015s)
# Wiedemann generated min poly is correct
# ---
# Case 23... Valid solution: attempt #1
# Finished Wiedemann in 1.627s (1 attempt)
# Solution verified against Sage built-in solver (0.018s)
# Wiedemann generated min poly is correct
# ---
# Case 24... Valid solution: attempt #1
# Finished Wiedemann in 1.347s (1 attempt)
# Solution verified against Sage built-in solver (0.013s)
# Wiedemann generated min poly is correct
# ---
# Case 25... Valid solution: attempt #1
# Finished Wiedemann in 4.805s (1 attempt)
# Solution verified against Sage built-in solver (0.037s)
# Wiedemann generated min poly is correct
# ---
# Case 26... Valid solution: attempt #1
# Finished Wiedemann in 4.483s (1 attempt)
# Solution verified against Sage built-in solver (0.038s)
# Wiedemann generated min poly is correct
# ---
# Case 27... Valid solution: attempt #1
# Finished Wiedemann in 4.005s (1 attempt)
# Solution verified against Sage built-in solver (0.037s)
# Wiedemann generated min poly is correct
# ---
# Case 28... Valid solution: attempt #1
# Finished Wiedemann in 4.653s (1 attempt)
# Solution verified against Sage built-in solver (0.040s)
# Wiedemann generated min poly is correct
# ---
# Case 29... Valid solution: attempt #1
# Finished Wiedemann in 0.526s (1 attempt)
# Solution verified against Sage built-in solver (0.007s)
# Wiedemann generated min poly is correct
# ---
# Case 30... Valid solution: attempt #1
# Finished Wiedemann in 0.724s (1 attempt)
# Solution verified against Sage built-in solver (0.008s)
# Wiedemann generated min poly is correct
# Failed 0 cases
